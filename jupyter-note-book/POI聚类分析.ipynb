# %% [markdown]
# ## 安装pyclustering
# ```shell
# pip3 install pyclustering
# ```

# %% [markdown]
# ### kmeans example

# %%
from pyclustering.cluster.kmeans import kmeans, kmeans_visualizer
from pyclustering.cluster.center_initializer import kmeans_plusplus_initializer
from pyclustering.samples.definitions import FCPS_SAMPLES
from pyclustering.utils import read_sample
# Load list of points for cluster analysis.
sample = read_sample(FCPS_SAMPLES.SAMPLE_TWO_DIAMONDS)
# Prepare initial centers using K-Means++ method.
initial_centers = kmeans_plusplus_initializer(sample, 2).initialize()
# Create instance of K-Means algorithm with prepared centers.
kmeans_instance = kmeans(sample, initial_centers)
# Run cluster analysis and obtain results.
kmeans_instance.process()
clusters = kmeans_instance.get_clusters()
final_centers = kmeans_instance.get_centers()
# Visualize obtained results
kmeans_visualizer.show_clusters(sample, clusters, final_centers)

# %% [markdown]
# ### DBSCAN example

# %%
from pyclustering.cluster.dbscan import dbscan
from pyclustering.cluster import cluster_visualizer
from pyclustering.utils import read_sample
from pyclustering.samples.definitions import FCPS_SAMPLES
# Sample for cluster analysis.
sample = read_sample(FCPS_SAMPLES.SAMPLE_CHAINLINK)
# Create DBSCAN algorithm.
dbscan_instance = dbscan(sample, 0.7, 3)
# Start processing by DBSCAN.
dbscan_instance.process()
# Obtain results of clustering.
clusters = dbscan_instance.get_clusters()
noise = dbscan_instance.get_noise()
# Visualize clustering results
visualizer = cluster_visualizer()
visualizer.append_clusters(clusters, sample)
visualizer.append_cluster(noise, sample, marker='x')
visualizer.show()

# %% [markdown]
# ## 数据预处理

# %%
import os
path = '武汉POI/CSV版本/'
files= os.listdir(path) #得到文件夹下的所有文件名称
print(files)
# Out:
# ['交通设施服务.csv', '住宿服务.csv', '体育休闲服务.csv', '公共设施.xlsx.csv', '公司企业.csv', '医疗保险服务..csv', '商务住宅.csv', '政府机构及社会团体.csv', '生活服务.csv', '科教文化服务.csv', '购物服务.csv', '金融保险服务.csv', '风景名胜.csv', '餐饮.csv']

# %%
import csv

for name in files:
    file_read = open('武汉POI/CSV版本/' + name, 'r',encoding='gbk')
    with file_read:
        reader = csv.reader(file_read)
        print('writing : ' + name )
        for row in reader:
            if(row[8]=='WGS84_经度'):
                continue;
            file_write = open('武汉POI/CSV版本/' + name + '_predeal.csv', 'a')
            with file_write:
                file_write.write(row[8]+ " " + row[9] + '\n')
# Out:
# writing : 交通设施服务.csv
# writing : 住宿服务.csv
# writing : 体育休闲服务.csv
# writing : 公共设施.xlsx.csv
# writing : 公司企业.csv
# writing : 医疗保险服务..csv
# writing : 商务住宅.csv
# writing : 政府机构及社会团体.csv
# writing : 生活服务.csv
# writing : 科教文化服务.csv
# writing : 购物服务.csv
# writing : 金融保险服务.csv
# writing : 风景名胜.csv
# writing : 餐饮.csv

# %% [markdown]
# ## POI聚类分析

# %% [markdown]
# ### 交通设施服务

# %% [markdown]
# #### kmeans 聚类

# %%
# Load list of points for cluster analysis.
sample = read_sample('武汉POI/CSV版本/交通设施服务.csv_predeal.csv')
# Prepare initial centers using K-Means++ method.
initial_centers = kmeans_plusplus_initializer(sample, 5).initialize()
# Create instance of K-Means algorithm with prepared centers.
kmeans_instance = kmeans(sample, initial_centers)
# Run cluster analysis and obtain results.
kmeans_instance.process()
clusters = kmeans_instance.get_clusters()
final_centers = kmeans_instance.get_centers()
# Visualize obtained results
kmeans_visualizer.show_clusters(sample, clusters, final_centers)

# %% [markdown]
# #### DBSCAN

# %%
# Sample for cluster analysis.
sample = read_sample('武汉POI/CSV版本/交通设施服务.csv_predeal.csv')
# Create DBSCAN algorithm.
dbscan_instance = dbscan(sample, 0.05, 3)
# Start processing by DBSCAN.
dbscan_instance.process()
# Obtain results of clustering.
clusters = dbscan_instance.get_clusters()
noise = dbscan_instance.get_noise()
# Visualize clustering results
visualizer = cluster_visualizer()
visualizer.append_clusters(clusters, sample)
visualizer.append_cluster(noise, sample, marker='x')
visualizer.show()

# %% [markdown]
# ### 住宿服务

# %% [markdown]
# #### kmeans

# %%
# Load list of points for cluster analysis.
sample = read_sample('武汉POI/CSV版本/住宿服务.csv_predeal.csv')
# Prepare initial centers using K-Means++ method.
initial_centers = kmeans_plusplus_initializer(sample, 5).initialize()
# Create instance of K-Means algorithm with prepared centers.
kmeans_instance = kmeans(sample, initial_centers)
# Run cluster analysis and obtain results.
kmeans_instance.process()
clusters = kmeans_instance.get_clusters()
final_centers = kmeans_instance.get_centers()
# Visualize obtained results
kmeans_visualizer.show_clusters(sample, clusters, final_centers)

# %% [markdown]
# #### DBSCAN

# %%
# Sample for cluster analysis.
sample = read_sample('武汉POI/CSV版本/住宿服务.csv_predeal.csv')
# Create DBSCAN algorithm.
dbscan_instance = dbscan(sample, 0.05, 3)
# Start processing by DBSCAN.
dbscan_instance.process()
# Obtain results of clustering.
clusters = dbscan_instance.get_clusters()
noise = dbscan_instance.get_noise()
# Visualize clustering results
visualizer = cluster_visualizer()
visualizer.append_clusters(clusters, sample)
visualizer.append_cluster(noise, sample, marker='x')
visualizer.show()

# %% [markdown]
# ### 公司企业

# %% [markdown]
# #### kmeans

# %%
# Load list of points for cluster analysis.
sample = read_sample('武汉POI/CSV版本/公司企业.csv_predeal.csv')
# Prepare initial centers using K-Means++ method.
initial_centers = kmeans_plusplus_initializer(sample, 5).initialize()
# Create instance of K-Means algorithm with prepared centers.
kmeans_instance = kmeans(sample, initial_centers)
# Run cluster analysis and obtain results.
kmeans_instance.process()
clusters = kmeans_instance.get_clusters()
final_centers = kmeans_instance.get_centers()
# Visualize obtained results
kmeans_visualizer.show_clusters(sample, clusters, final_centers)

# %% [markdown]
# #### DBSCAN

# %%
# Sample for cluster analysis.
sample = read_sample('武汉POI/CSV版本/公司企业.csv_predeal.csv')
# Create DBSCAN algorithm.
dbscan_instance = dbscan(sample, 0.05, 3)
# Start processing by DBSCAN.
dbscan_instance.process()
# Obtain results of clustering.
clusters = dbscan_instance.get_clusters()
noise = dbscan_instance.get_noise()
# Visualize clustering results
visualizer = cluster_visualizer()
visualizer.append_clusters(clusters, sample)
visualizer.append_cluster(noise, sample, marker='x')
visualizer.show()

# %% [markdown]
# ### 生活服务

# %% [markdown]
# #### kmeans

# %%
# Load list of points for cluster analysis.
sample = read_sample('武汉POI/CSV版本/生活服务.csv_predeal.csv')
# Prepare initial centers using K-Means++ method.
initial_centers = kmeans_plusplus_initializer(sample, 5).initialize()
# Create instance of K-Means algorithm with prepared centers.
kmeans_instance = kmeans(sample, initial_centers)
# Run cluster analysis and obtain results.
kmeans_instance.process()
clusters = kmeans_instance.get_clusters()
final_centers = kmeans_instance.get_centers()
# Visualize obtained results
kmeans_visualizer.show_clusters(sample, clusters, final_centers)

# %% [markdown]
# #### DBSCAN

# %%
# Sample for cluster analysis.
sample = read_sample('武汉POI/CSV版本/生活服务.csv_predeal.csv')
# Create DBSCAN algorithm.
dbscan_instance = dbscan(sample, 0.05, 3)
# Start processing by DBSCAN.
dbscan_instance.process()
# Obtain results of clustering.
clusters = dbscan_instance.get_clusters()
noise = dbscan_instance.get_noise()
# Visualize clustering results
visualizer = cluster_visualizer()
visualizer.append_clusters(clusters, sample)
visualizer.append_cluster(noise, sample, marker='x')
visualizer.show()

# %% [markdown]
# ### 风景名胜

# %% [markdown]
# #### kmeans

# %%
# Load list of points for cluster analysis.
sample = read_sample('武汉POI/CSV版本/风景名胜.csv_predeal.csv')
# Prepare initial centers using K-Means++ method.
initial_centers = kmeans_plusplus_initializer(sample, 5).initialize()
# Create instance of K-Means algorithm with prepared centers.
kmeans_instance = kmeans(sample, initial_centers)
# Run cluster analysis and obtain results.
kmeans_instance.process()
clusters = kmeans_instance.get_clusters()
final_centers = kmeans_instance.get_centers()
# Visualize obtained results
kmeans_visualizer.show_clusters(sample, clusters, final_centers)

# %% [markdown]
# #### DBSCAN

# %%
# Sample for cluster analysis.
sample = read_sample('武汉POI/CSV版本/风景名胜.csv_predeal.csv')
# Create DBSCAN algorithm.
dbscan_instance = dbscan(sample, 0.05, 3)
# Start processing by DBSCAN.
dbscan_instance.process()
# Obtain results of clustering.
clusters = dbscan_instance.get_clusters()
noise = dbscan_instance.get_noise()
# Visualize clustering results
visualizer = cluster_visualizer()
visualizer.append_clusters(clusters, sample)
visualizer.append_cluster(noise, sample, marker='x')
visualizer.show()
